# %%
import lxml.html as ls
import requests
import bs4

# %%
res= requests.get('https://sanantoniobeerfestival.com')

# %%
type(res)
# Out:
# requests.models.Response

# %%
res.text
# Out:
# '<!DOCTYPE html>\n<html lang="en-US">\n<head >\n<meta charset="UTF-8" />\n<meta name="viewport" content="width=device-width, initial-scale=1" />\n<title>2019 San Antonio Beer Festival •\xa0Saturday, October 19, 2019</title>\n\n<!-- This site is optimized with the Yoast SEO plugin v12.1 - https://yoast.com/wordpress/plugins/seo/ -->\n<meta name="description" content="The 13th Annual San Antonio Beer Festival features 400+ premium and craft beers from 125+ breweries from around the world."/>\n<link rel="canonical" href="https://sanantoniobeerfestival.com/" />\n<meta property="og:locale" content="en_US" />\n<meta property="og:type" content="website" />\n<meta property="og:title" content="2019 San Antonio Beer Festival •\xa0Saturday, October 19, 2019" />\n<meta property="og:description" content="The 13th Annual San Antonio Beer Festival features 400+ premium and craft beers from 125+ breweries from around the world." />\n<meta property="og:url" content="https://sanantoniobeerfestival.com
# ...

# %%
soup = bs4.BeautifulSoup(res.text, 'lxml')

# %%
type(soup)
a = soup.find_all('h2')
beer_list =[aa.decode_contents() for aa in a]
beer_list
# Out:
# ['Saturday, October 19, 2019',
#  'Participate',
#  'Breweries',
#  'H-E-B Beer Experience',
#  '2018 Entertainment',
#  'Sponsors',
#  'Location',
#  'Parking',
#  'Getting there',
#  'Experience',
#  'Photos']

# %%
c= soup.find_all('strong')
beer_type= [cc.decode_contents() for cc in c]
beer_type
# Out:
# ['1:30 pm',
#  '2:15 pm',
#  '3:30 pm',
#  '5:10 pm',
#  'SABEERFEST18',
#  'SABFESTVIP18',
#  'Compete in the Burpee and Squat Challenge!',
#  'ROUND\xa01-<br/>\n',
#  'ROUND 2-',
#  'ROUND 3-']

# %%
beer_list
# Out:
# []

# %%
len(beer_name)
# Out:
# 0

# %%
soup.find_all('class', {'class' = 'beer-details'})
# Out:
#   File "<ipython-input-22-47274570b17d>", line 1
#     soup.find_all('class', {'class' = 'beer-details'})
#                                     ^
# SyntaxError: invalid syntax
